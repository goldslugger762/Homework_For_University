# %%
from rich import print
from rich.console import Console

console = Console()


print("[bold yellow]Привет!\nХочешь ли ты сняться в фильме?")
question = console.input("[bold green4][Да/Нет]: ")

if question.lower() == 'да':
    agreed = console.input("[bold yellow]Отлично!\nА какую роль ты бы хотел выбрать?\nЕсть роль [bold green4]Локи и Халка!\n")
    if "халк" in agreed.lower():
        biceps = console.input("[bold yellow]А сколько у тебя бицепс в объёме?\n")
        biceps_number = int(biceps)
        if biceps_number >= int(60):
            print("[bold green_yellow]Отлично! Ты принят!")
        elif biceps_number < 60:
            print ("[bold underline red]Иди домой...")
        else: print("[italic black on red]Прости, я тебя не совсем понимаю")
        
    elif "лок" in agreed.lower():
        motherfather = console.input("[bold yellow]А кого ты больше любишь?\n[bold green4]Маму или папу?\n")
        if "мам" in motherfather.lower():
                 print("[bold yellow]Точно?\nСходи к папе, узнай кого больше любишь!")
        elif "пап" in motherfather.lower():
                 print ("[bold underline red]Иди домой...") 
        else: print("[italic black on red]Прости, я тебя не совсем понимаю")

elif question.lower() == 'нет':
    print("[bold red]Эхх... А жаль!\nДо новой встречи!")
else: print("[italic black on red]Прости, я тебя не совсем понимаю")
# Out:
# Привет!
# Хочешь ли ты сняться в фильме?
