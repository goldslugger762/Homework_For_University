# %%
from my_functions import greet, change_name

input_name = input("Введите имя: ")
new_name = change_name("Johnattan")
new_name2 = change_name(input_name)

greet(new_name)
greet(new_name2)

greet("Johnbert")
# Out:
# Hello JoHnAtTaN!
# Hello jOhNaTtAn!
# Hello Johnbert!
